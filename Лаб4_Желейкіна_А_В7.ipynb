# %% [markdown]
# <a href="https://colab.research.google.com/github/Zheleikina/NM/blob/main/%D0%9B%D0%B0%D0%B14_%D0%96%D0%B5%D0%BB%D0%B5%D0%B9%D0%BA%D1%96%D0%BD%D0%B0_%D0%90_%D0%927.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Желейкіна Аліна. Варіант 7. Була присутня на парі

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
matrix = np.random.randint(1, 6, size=(3,3))

matrix
# Out:
# array([[2, 1, 2],
#        [3, 5, 4],
#        [4, 4, 4]])

# %%
det = np.linalg.det(matrix)
det
# Out:
# np.float64(-3.999999999999999)

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(15360)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(15360)

# %%
np.sum(matrix)
# Out:
# np.int64(29)

# %%
np.max(matrix)
# Out:
# np.int64(5)

# %%
np.min(matrix)
# Out:
# np.int64(1)

# %%
np.mean(matrix)
# Out:
# np.float64(3.2222222222222223)

# %%
max_element = np.max(matrix)
print ("Максимальне значення елементів матриці:", max_element)
# Out:
# Максимальне значення елементів матриці: 5

# %%
min_element = np.min(matrix)
print ("Мінімальне значення елементів матриці:", min_element)
# Out:
# Мінімальне значення елементів матриці: 1

# %%
mean = np.mean(matrix)
print ("Середнє значення елементів матриці:", mean)
# Out:
# Середнє значення елементів матриці: 3.2222222222222223

# %%
sqrt_matrix = np.sqrt(matrix)

print ("Матриця квадратних коренів:")
print (sqrt_matrix)
# Out:
# Матриця квадратних коренів:
# [[1.41421356 1.         1.41421356]
#  [1.73205081 2.23606798 2.        ]
#  [2.         2.         2.        ]]

# %%
row_sum = np.sum(matrix, axis=1).reshape (-1,1)
print (row_sum)
# Out:
# [[ 5]
#  [12]
#  [12]]

# %%
matrix.sum(axis=1).reshape(-1,1)
# Out:
# array([[ 5],
#        [12],
#        [12]])

# %%
x = np.matrix ([[1, 2], [4, 3]])
x
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
x.sum(axis=1)
# Out:
# matrix([[3],
#         [7]])

# %%
x.sum(axis=1, dtype="float")
# Out:
# matrix([[3.],
#         [7.]])

# %%
vector = np.random.randint(0, 10, size=25)
vector
# Out:
# array([8, 1, 3, 8, 7, 2, 1, 6, 9, 6, 5, 2, 0, 6, 1, 5, 1, 0, 1, 2, 8, 3,
#        4, 7, 1])

# %%
sorted_vector = np.sort(vector)[::-1]
sorted_vector
# Out:
# array([9, 8, 8, 8, 7, 7, 6, 6, 6, 5, 5, 4, 3, 3, 2, 2, 2, 1, 1, 1, 1, 1,
#        1, 0, 0])

# %%
from scipy import stats
mode = stats.mode(vector)
median = np.median(vector)
mean = np.mean(vector)
max_value = np.max(vector)
min_value = np.min(vector)
print ("Мода:", mode)
print ("Медіана:", median)
print ("Середнє значення:", mean)
print ("Максимальне значення:", max_value)
print ("Мінімальне значення:", min_value)
# Out:
# Мода: ModeResult(mode=np.int64(1), count=np.int64(6))
# Медіана: 3.0
# Середнє значення: 3.88
# Максимальне значення: 9
# Мінімальне значення: 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a = np.array([
    [3, -5, 3],
    [1, 2, 1],
    [2, 7, -1],
])
b = np.array([[1], [4], [8]])

# %%
#Матричний метод (1 спосіб)
det_a = np.linalg.det(a)
if det_a == 0:
    print("Визначник дорівнює нулю - рішень немає")
else:
  a_inv = np.linalg.inv(a)
  print(f"Обернена матриця до матриці A: \r\n {a_inv }")
  print(f"Вектор рішення: \r\n {a_inv.dot(b)}")
# Out:
# Обернена матриця до матриці A:
#  [[ 0.27272727 -0.48484848  0.33333333]
#  [-0.09090909  0.27272727  0.        ]
#  [-0.09090909  0.93939394 -0.33333333]]
# Вектор рішення:
#  [[1.]
#  [1.]
#  [1.]]

# %%
# Напиши функцію для вирішення системи матричним методом (2 спосіб)
def solve_inv_matrix(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    a_inv= np.linalg.inv(a)
    if verbose: print(f"Обернена матриця до матриці A: \r\n {a_inv }")
    return a_inv.dot(b)

print(f"Вектор рішення: \r\n {solve_inv_matrix(a, b)}")
# Out:
# Вектор рішення:
#  [[1.]
#  [1.]
#  [1.]]

# %%
#метод Крамера (1 спосіб)
# Метод Крамера
det_a = np.linalg.det(a)

if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    def replace_column(matrix, column_index, new_column):
        new_matrix = np.copy(matrix)
        new_matrix[:, column_index] = new_column
        return new_matrix

    # Обчислюємо Δx, Δy, Δz
    delta_x = np.linalg.det(replace_column(a, 0, b.T))
    delta_y = np.linalg.det(replace_column(a, 1, b.T))
    delta_z = np.linalg.det(replace_column(a, 2, b.T))

    # Обчислюємо x, y, z
    print('x =', delta_x / det_a)
    print('y =', delta_y / det_a)
    print('z =', delta_z / det_a)
# Out:
# x = 1.0
# y = 1.0000000000000004
# z = 1.0

# %%
# Напиши функцію для вирішення системи методом Крамера
def solve_cramer(a, b, verbose=False):
    det = np.linalg.det(a)
    if verbose: print(f"Визначник матриці A: {round(det)}")
    if det == 0:
        print("Визначник дорівнює нулю - рішень немає")
        return None

    len_a = len(a)
    x = np.zeros((len_a, 1))
    for i in range(len_a):
        temp = np.copy(a)
        temp[:, [i]] = b
        x[i, 0] = np.linalg.det(temp)/det

    return x


print(f"Вектор рішення: \r\n {solve_cramer(a, b)}")
# Out:
# Вектор рішення:
#  [[1.]
#  [1.]
#  [1.]]

# %% [markdown]
# Перевірка

# %%
x = np.linalg.solve(a, b)

print(x)
# Out:
# [[1.]
#  [1.]
#  [1.]]
